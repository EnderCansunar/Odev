# %%
d1={"isim":"Ender","soyisim":"Cansunar", "Doğum_Tarihi":1987}
d2={"isim":"Omer","soyisim":"Cengiz", "Doğum_Tarihi":2000}
d3={"isim":"Hakan","soyisim":"Doktor", "Doğum_Tarihi":1950}
d4={"isim":"Neslihan","soyisim":"Deniz", "Doğum_Tarihi":1967}
d5={"isim":"Ayşe","soyisim":"Talih", "Doğum_Tarihi":2005}

tcv={1:d1,2:d2, 3:d3, 4:d4, 5:d5}
for k,v in tcv.items():
  print(k,".kişinin:"+"İsmi", v["isim"],"Soyisimi",v["soyisim"],"Doğum Tarihi",v["Doğum_Tarihi"])
# Out:
# 1 .kişinin:İsmi Ender Soyisimi Cansunar Doğum Tarihi 1987
# 2 .kişinin:İsmi Omer Soyisimi Cengiz Doğum Tarihi 2000
# 3 .kişinin:İsmi Hakan Soyisimi Doktor Doğum Tarihi 1950
# 4 .kişinin:İsmi Neslihan Soyisimi Deniz Doğum Tarihi 1967
# 5 .kişinin:İsmi Ayşe Soyisimi Talih Doğum Tarihi 2005
